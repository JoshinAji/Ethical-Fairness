# %%
import pandas as pd
v1 = pd.read_csv("../data/labels_v1.csv")
v3_cols = ["race_ml","skin_tone_bin","cultural_markers",
           "ambiguous_mixed","prefer_not_to_label","unknown_uncertain",
           "conf_race","conf_gender","conf_skin","annotation_notes"]
v3 = v1.copy()
for c in v3_cols: v3[c] = ""
v3.to_csv("../data/labels_v3.csv", index=False)
print("V3 scaffold created. Open data/labels_v3.csv in your preferred annotator.")
# Out:
# V3 scaffold created. Open data/labels_v3.csv in your preferred annotator.
